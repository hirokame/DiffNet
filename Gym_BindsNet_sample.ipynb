# %%
import torch
import gym
import gym_maze
from bindsnet.network import Network
from bindsnet.pipeline import EnvironmentPipeline as Pipeline
from bindsnet.encoding import bernoulli
from bindsnet.network.topology import Connection
from bindsnet.environment import GymEnvironment
from bindsnet.network.nodes import Input, LIFNodes
from bindsnet.pipeline.action import select_softmax

# %%
network = Network(dt = 1.0)

inpt = Input(n=2, traces=True)
middle = LIFNodes(n=10, traces=True)
out = LIFNodes(n=4, refrac=0, traces=True)


inpt_middle = Connection(source=inpt, target=middle, wmin=0, wmax=1e-1)
middle_out = Connection(source=middle, target=out, wmin=0, wmax=1)

middle_monitor = Monitor(obj=middle, state_vars=("s","v"), time=time)
out_monitor = Monitor(obj=out, state_vars=("s","v"), time=time)


network.add_layer(inpt, name="Input Layer")
network.add_layer(middle, name="Hidden Layer")
network.add_layer(out, name="Output Layer")
network.add_connection(inpt_middle, source="Input Layer", target="Hidden Layer")
network.add_connection(middle_out, source="Hidden_Layer", target="Output Layer")
network.add_monitor(monitor=middle_monitor, name="Hidden Layer")
network.add_monitor(monitor=out_monitor, name="Output Layer")

environment = GymEnvironment("maze-random-3x3-v0")
environment.reset()

pipeline = Pipeline(network, environment, encoding=bernoulli,
                    action_function=select_softmax, output="Output Layer",
                    time=100, history_length=1, delta=1,
                    plot_interval=1, render_interval=1)
"""

~algorhythm~

for step num:
    reset variables:
    while task not completed:
        gain step in environment
        acquire new observation
        transform observation into SNN input
        network run
        record spike history and reward history
        
"""

for i in range(50):
    reward=0
    pipeline.reset_state_variables()#reset the pipeline.
    action = 0
    while True:
        envstep = list(pipeline.env_step())#Gain one step and acquire the observation on the next environment[tensor(new position)、-1or1(reward)、Boolian(Is the task done? or not)、]を得る。
        if envstep[1] == 1:
            envstep[1] = 1.0
        pipeline.step(envstep)#Run a single iteration of the network and update it and the reward list when done.
        reward += envstep[1]
        if envstep[2]:
            break
    print("Episode"+str(i)+"reward:", reward)
# Out:
# Episode0reward: -53.0
# Episode1reward: -12.0
# Episode2reward: -24.0
# Episode3reward: -31.0
# Episode4reward: -11.0
# Episode5reward: -67.0
# Episode6reward: -3.0
# Episode7reward: -16.0
# Episode8reward: -20.0
# Episode9reward: -33.0
# Episode10reward: -112.0
# Episode11reward: -90.0
# Episode12reward: -40.0
# Episode13reward: -112.0
# Episode14reward: -31.0
# Episode15reward: -16.0
# Episode16reward: -63.0
# Episode17reward: -42.0
# Episode18reward: -48.0
# Episode19reward: -8.0
# Episode20reward: -32.0
# Episode21reward: -67.0
# Episode22reward: -80.0
# Episode23reward: -129.0
# Episode24reward: -79.0
# Episode25reward: -102.0
# Episode26reward: -26.0
# Episode27reward: -51.0
# Episode28reward: -71.0
# Episode29reward: -31.0
# Episode30reward: -166.0
# Episode31reward: -62.0
# Episode32reward: -45.0
# Episode33reward: -33.0
# Episode34reward: -98.0
# Episode35reward: -28.0
# Episode36reward: -19.0
# Episode37reward: -82.0
# Episode38reward: -278.0
# Episode39reward: -25.0
# ...
